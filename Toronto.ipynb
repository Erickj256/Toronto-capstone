# %% [markdown]
# ## part 1

# %%
# !pip install beautifulsoup4
# !pip install geocoder
# !pip install folium
import requests
from bs4 import BeautifulSoup
import pandas as pd
import folium
from geopy.geocoders import Nominatim

print('listo')
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\josaf\appdata\local\continuum\anaconda3\lib\site-packages (4.8.0)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\josaf\appdata\local\continuum\anaconda3\lib\site-packages (from beautifulsoup4) (1.9.3)
# Requirement already satisfied: geocoder in c:\users\josaf\appdata\local\continuum\anaconda3\lib\site-packages (1.38.1)
# Requirement already satisfied: six in c:\users\josaf\appdata\local\continuum\anaconda3\lib\site-packages (from geocoder) (1.12.0)
# Requirement already satisfied: requests in c:\users\josaf\appdata\local\continuum\anaconda3\lib\site-packages (from geocoder) (2.22.0)
# Requirement already satisfied: ratelim in c:\users\josaf\appdata\local\continuum\anaconda3\lib\site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: future in c:\users\josaf\appdata\local\continuum\anaconda3\lib\site-packages (from geocoder) (0.17.1)
# Requirement already satisfied: click in c:\users\josaf\appdata\local\continuum\anaconda3\lib\site-packages (from geocoder) (7.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\josaf\appdata\local\continuum\anaconda3\lib\site-packages (from requests->geocoder) (2019.9.11)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\josaf\appdata\local\continuum\anaconda3\lib\site-packages (from requests->geocoder) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\josaf\appdata\local\continuum\anaconda3\lib\site-packages (from requests->geocoder) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\josaf\appdata\local\continuum\anaconda3\lib\site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: decorator in c:\users\josaf\appdata\local\continuum\anaconda3\lib\site-packages (from ratelim->geocoder) (4.4.0)
# Requirement already satisfied: folium in c:\users\josaf\appdata\local\continuum\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: branca in c:\users\josaf\appdata\local\continuum\anaconda3\lib\site-packages (from folium) (0.4.0)
# Requirement already satisfied: jinja2 in c:\users\josaf\appdata\local\continuum\anaconda3\lib\site-packages (from folium) (2.10.3)
# Requirement already satisfied: requests in c:\users\josaf\appdata\local\continuum\anaconda3\lib\site-packages (from folium) (2.22.0)
# Requirement already satisfied: six in c:\users\josaf\appdata\local\continuum\anaconda3\lib\site-packages (from folium) (1.12.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\josaf\appdata\local\continuum\anaconda3\lib\site-packages (from jinja2->folium) (1.1.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\josaf\appdata\local\continuum\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\josaf\appdata\local\continuum\anaconda3\lib\site-packages (from requests->folium) (2019.9.11)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\josaf\appdata\local\continuum\anaconda3\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\josaf\appdata\local\continuum\anaconda3\lib\site-packages (from requests->folium) (1.24.2)
# listo

# %%
page = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
soup = BeautifulSoup(page.content, 'html.parser')
table = soup.find('table', class_='wikitable')
table_rows = table.find_all('tr')

# %%
temp = []

# adding invidual subarrays for each table array
for tr in table_rows:
    td = tr.find_all('td')
    row = [d.text.strip() for d in td]

    # excluding rows whose borough is not assigned
    if row and row[1] != 'Not assigned':
        # in case post code don't have neighbourhood assigned
        if row[2] == 'Not assigned':
            row[2] = row[1]
        temp.append(row)

# %%
# creating dataframe out of mentioned array
df = pd.DataFrame(data=temp, columns=['Postcode', 'Borough', 'Neighbourhood'])
print(df.shape)
# creating temporary data frame of neighbourhood seprated by comma's for each postcode
tempNeighbourhoodDf =df.groupby('Postcode')['Neighbourhood'].apply(','.join).reset_index().set_index('Postcode')

#droping rows and joining above dataframes 
df = df.drop('Neighbourhood', axis=1).drop_duplicates().set_index('Postcode')
df = df.join(tempNeighbourhoodDf)
df
# Out:
# (103, 3)
#                    Borough                                      Neighbourhood
# Postcode
# M3A             North York                                          Parkwoods
# M4A             North York                                   Victoria Village
# M5A       Downtown Toronto                         Regent Park / Harbourfront
# M6A             North York                  Lawrence Manor / Lawrence Heights
# M7A       Downtown Toronto       Queen's Park / Ontario Provincial Government
# ...                    ...                                                ...
# M8X              Etobicoke   The Kingsway / Montgomery Road  / Old Mill North
# M4Y       Downtown Toronto                               Church and Wellesley
# M7Y           East Toronto              Business reply mail Processing CentrE
# M8Y              Etobicoke  Old Mill South / King's Mill Park / Sunnylea /...
# M8Z              Etobicoke  Mimico NW / The Queensway West / South of Bloo...
#
# [103 rows x 2 columns]

# %%
print("Shape of final data frame", df.shape)
# Out:
# Shape of final data frame (103, 4)

# %%
import geocoder

def fetchLatLng(postal_code):

    # iniitalize your variable to none
    lat_lng_words = None

    # loop until you get coordinates
    while(lat_lng_words is None):
        g = geocoder.google('{}, Toronto, Ontaria'.format(postal_code))
        lat_lng_words = g.latlng

    latitude = lat_lng_words[0]
    longitude = lat_lng_words[1]
    print('Latitude: {} & longitude: {}'.format(latitude, longitude))
    return

# %%
locationDf = pd.read_csv('./Geospatial_Coordinates.csv').set_index('Postal Code')
df = df.join(locationDf)
torontoDf = df[df['Borough'].str.contains("Toronto")]
torontoDf
# Out:
#                    Borough                                      Neighbourhood  \
# Postcode
# M5A       Downtown Toronto                         Regent Park / Harbourfront
# M7A       Downtown Toronto       Queen's Park / Ontario Provincial Government
# M5B       Downtown Toronto                           Garden District, Ryerson
# M5C       Downtown Toronto                                     St. James Town
# M4E           East Toronto                                        The Beaches
# M5E       Downtown Toronto                                        Berczy Park
# M5G       Downtown Toronto                                 Central Bay Street
# M6G       Downtown Toronto                                           Christie
# M5H       Downtown Toronto                         Richmond / Adelaide / King
# M6H           West Toronto                      Dufferin / Dovercourt Village
# M5J       Downtown Toronto  Harbourfront East / Union Station / Toronto Is...
# M6J           West Toronto                          Little Portugal / Trinity
# M4K           East Toronto                      The Danforth West / Riverdale
# M5K       Downtown Toronto          Toronto Dominion Centre / Design Exchange
# M6K           West Toronto     Brockton / Parkdale Village / Exhibition Place
# M4L           East Toronto                    India Bazaar / The Beaches West
# M5L       Downtown Toronto                    Commerce Court / Victoria Hotel
# M4M           East Toronto                                    Studio District
# M4N        Central Toronto                                      Lawrence Park
# M5N        Central Toronto                                           Roselawn
# M4P        Central Toronto                                   Davisville North
# M5P        Central Toronto                           Forest Hill North & West
# M6P           West Toronto                     High Park / The Junction South
# M4R        Central Toronto                                 North Toronto West
# M5R        Central Toronto              The Annex / North Midtown / Yorkville
# M6R           West Toronto                            Parkdale / Roncesvalles
# M4S        Central Toronto                                         Davisville
# M5S       Downtown Toronto                    University of Toronto / Harbord
# M6S           West Toronto                                Runnymede / Swansea
# M4T        Central Toronto                       Moore Park / Summerhill East
# M5T       Downtown Toronto        Kensington Market / Chinatown / Grange Park
# M4V        Central Toronto  Summerhill West / Rathnelly / South Hill / For...
# M5V       Downtown Toronto  CN Tower / King and Spadina / Railway Lands / ...
# M4W       Downtown Toronto                                           Rosedale
# M5W       Downtown Toronto                                     Stn A PO Boxes
# M4X       Downtown Toronto                       St. James Town / Cabbagetown
# M5X       Downtown Toronto            First Canadian Place / Underground city
# M4Y       Downtown Toronto                               Church and Wellesley
# M7Y           East Toronto              Business reply mail Processing CentrE
#
#            Latitude  Longitude
# Postcode
# M5A       43.654260 -79.360636
# M7A       43.662301 -79.389494
# M5B       43.657162 -79.378937
# M5C       43.651494 -79.375418
# M4E       43.676357 -79.293031
# M5E       43.644771 -79.373306
# M5G       43.657952 -79.387383
# M6G       43.669542 -79.422564
# M5H       43.650571 -79.384568
# M6H       43.669005 -79.442259
# M5J       43.640816 -79.381752
# M6J       43.647927 -79.419750
# M4K       43.679557 -79.352188
# M5K       43.647177 -79.381576
# M6K       43.636847 -79.428191
# M4L       43.668999 -79.315572
# M5L       43.648198 -79.379817
# M4M       43.659526 -79.340923
# M4N       43.728020 -79.388790
# M5N       43.711695 -79.416936
# M4P       43.712751 -79.390197
# M5P       43.696948 -79.411307
# M6P       43.661608 -79.464763
# M4R       43.715383 -79.405678
# M5R       43.672710 -79.405678
# M6R       43.648960 -79.456325
# M4S       43.704324 -79.388790
# M5S       43.662696 -79.400049
# M6S       43.651571 -79.484450
# M4T       43.689574 -79.383160
# M5T       43.653206 -79.400049
# M4V       43.686412 -79.400049
# M5V       43.628947 -79.394420
# M4W       43.679563 -79.377529
# M5W       43.646435 -79.374846
# M4X       43.667967 -79.367675
# M5X       43.648429 -79.382280
# M4Y       43.665860 -79.383160
# M7Y       43.662744 -79.321558

# %%
# geocoder is not working in my case
# getting lat, lng of Toronto
lat_lng_toronto = None

# loop until you get coordinates
while(lat_lng_toronto is None):
    print("fetching location")
    g = geocoder.google('Toronto, Ontaria')
    print("fetched location")
    lat_lng_toronto = g.latlng

lat_lng_toronto

# %%
print(lat_lng_toronto)

# %%
Citoronto_latitude = "43.6529"
toronto_longitude = "-79.3849"
map_toronto = folium. Map(location=[toronto_latitude, toronto_longitude], zoom_start=12)

for lat, lng, borough, neighbourhood in zip(torontoDf['Latitude'], torontoDf['Longitude'], torontoDf['Borough'], torontoDf['Neighbourhood']):
    label = '{}'.format(borough)
    label= folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=2,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False
    ).add_to(map_toronto)

map_toronto
